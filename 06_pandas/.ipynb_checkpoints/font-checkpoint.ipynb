# %%
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([ -78,  -21,  -23,  -51,  -91,  -39,    9,  -19,  -34,    4,   32,
#         -53, -135, -131, -142, -184, -137,  -75,   17,  -31,  -23,  -13,
#         -84,   13,  102,  201,  264,  346,  416,  498,  445,  364,  442,
#         410,  321,  406,  462,  386,  406,  396,  362,  444,  476,  505,
#         588,  630,  665,  594,  559,  476], dtype=int32)

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 1. 폰트파일로 FontProperties()생성 후 사용

import matplotlib.font_manager as fm
path = 'D2CodingBold-Ver1.3.2-20180524.ttf'
fontprop = fm.FontProperties(fname=path,size=15)
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식 가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#2. matplotlib.rcParams[]로 설정
import matplotlib
print('설정 파일 위치 :',matplotlib.matplotlib_fname())
print('기본 설정 폰트 :',plt.rcParams['font.family'])
print('기본 설정 사이즈 :',plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 : C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 : ['sans-serif']
# 기본 설정 사이즈 : 10.0

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus']=False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
fm.findSystemFonts()[:4]
# Out:
# ['C:\\WINDOWS\\Fonts\\CENSCBK.TTF',
#  'C:\\WINDOWS\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\WINDOWS\\Fonts\\LFAXD.TTF']

# %%
[f.name for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# ['NanumSquare Neo Light', 'NanumSquare Neo Regular']

# %%
plt.rcParams['font.family']='NanumSquare Neo Regular'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus']=False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#3. 설정파일 수정
print('설정 파일 위치 :',matplotlib.matplotlib_fname())
print('기본 설정 폰트 :',plt.rcParams['font.family'])
print('기본 설정 사이즈 :',plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 : C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 : ['NanumSquare Neo Regular']
# 기본 설정 사이즈 : 13.0
